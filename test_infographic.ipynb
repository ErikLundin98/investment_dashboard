# %%
import financial_data

p_met = financial_data.get_portfolio_metrics()
# Out:
# downloading prices, period: 1mo , tickers: {'AMD': 'USD', 'AAPL': 'USD', 'INVE-B.ST': 'SEK', 'NWARF': 'USD', 'NVDA': 'USD', 'PLTR': 'USD', 'SAS.ST': 'SEK', 'VOLV-B.ST': 'SEK', 'BTC-USD': 'USD', 'ETH-USD': 'USD', 'DOGE-USD': 'USD'}
# [*********************100%***********************]  11 of 11 completed
# [*********************100%***********************]  1 of 1 completed

# %%
p_met
# Out:
# {'last updated date': Timestamp('2021-12-20 00:00:00', freq='D'),
#  'time series': {'dates': DatetimeIndex(['2021-11-20', '2021-11-21', '2021-11-22', '2021-11-23',
#                  '2021-11-24', '2021-11-25', '2021-11-26', '2021-11-27',
#                  '2021-11-28', '2021-11-29', '2021-11-30', '2021-12-01',
#                  '2021-12-02', '2021-12-03', '2021-12-04', '2021-12-05',
#                  '2021-12-06', '2021-12-07', '2021-12-08', '2021-12-09',
#                  '2021-12-10', '2021-12-11', '2021-12-12', '2021-12-13',
#                  '2021-12-14', '2021-12-15', '2021-12-16', '2021-12-17',
#                  '2021-12-18', '2021-12-19', '2021-12-20'],
#                 dtype='datetime64[ns]', name='Date', freq='D'),
#   'crypto_ts': array([24179.36388171, 23684.68590741, 22730.1849365 , 23517.30305065,
#          23107.9451004 , 23575.93132754, 22042.25918287, 22524.44930255,
#          23453.01709654, 23954.95623263, 23679.79944051, 23543.37200999,
# ...

# %%
from matplotlib import pyplot as plt
plt.style.use('seaborn-paper')
#plt.rcParams['font.size'] = '8'
ts = p_met['time series']
fig, (ax1, ax2, ax3) = plt.subplots(3, sharex=True)
fig.set_size_inches(5, 5)
ax1.plot(ts['dates'], ts['total_ts'])
ax2.plot(ts['dates'], ts['crypto_ts'])
ax3.plot(ts['dates'], ts['stock_ts'])
ticks = ax1.get_xticks()
ax1.set_xticks([ticks[0], ticks[-1]])
ax1.tick_params(axis=u'both', which=u'both',length=0)
ax2.tick_params(axis=u'both', which=u'both',length=0)
ax3.tick_params(axis=u'both', which=u'both',length=0)
ax1.legend('total')
ax2.legend('crypto')
ax3.legend('stocks')
ax1.text(ts['dates'][-4], ts['total_ts'][-1], int(ts['total_ts'][-1]))
ax2.text(ts['dates'][-4], ts['crypto_ts'][-1], int(ts['crypto_ts'][-1]))
ax3.text(ts['dates'][-4], ts['stock_ts'][-1], int(ts['stock_ts'][-1]))
ax1.text(ts['dates'][0], ts['total_ts'][0], int(ts['total_ts'][-1]))
ax2.text(ts['dates'][0], ts['crypto_ts'][0], int(ts['crypto_ts'][-1]))
ax3.text(ts['dates'][0], ts['stock_ts'][0], int(ts['stock_ts'][-1]))
# ##for ax in [ax1, ax2, ax3]:
#     [spine.set_visible(False) for spine in ax.spines.values()]
#     l_spine = ax.spines['left']
# Out:
# Text(2021-11-20 00:00:00, 106619.12666126265, '95993')

# %%
from mpl_toolkits.axes_grid1 import host_subplot
import mpl_toolkits.axisartist as AA
import matplotlib.pyplot as plt

host = host_subplot(111, axes_class=AA.Axes)
plt.subplots_adjust(right=0.75)

par1 = host.twinx()
par2 = host.twinx()

offset = 60
new_fixed_axis = par2.get_grid_helper().new_fixed_axis
par2.axis["right"] = new_fixed_axis(loc="right", axes=par2,
                                        offset=(offset, 0))

par2.axis["right"].toggle(all=True)

host.set_xlabel("Date")
host.set_ylabel("Total")
par1.set_ylabel("Crypto")
par2.set_ylabel("Stocks")

p1, = host.plot(ts['dates'], ts['total_ts'], label="Total")
p2, = par1.plot(ts['dates'], ts['crypto_ts'], label="Crypto")
p3, = par2.plot(ts['dates'], ts['stock_ts'], label="Stocks")

#par1.set_ylim(0, 4)
#par2.set_ylim(1, 65)

host.legend()

host.axis["left"].label.set_color(p1.get_color())
par1.axis["right"].label.set_color(p2.get_color())
par2.axis["right"].label.set_color(p3.get_color())

plt.draw()
plt.show()

#plt.savefig("Test")

# %%
plt.style.available
# Out:
# ['Solarize_Light2',
#  '_classic_test_patch',
#  'bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'seaborn',
#  'seaborn-bright',
#  'seaborn-colorblind',
#  'seaborn-dark',
#  'seaborn-dark-palette',
#  'seaborn-darkgrid',
#  'seaborn-deep',
#  'seaborn-muted',
#  'seaborn-notebook',
#  'seaborn-paper',
#  'seaborn-pastel',
#  'seaborn-poster',
#  'seaborn-talk',
#  'seaborn-ticks',
#  'seaborn-white',
#  'seaborn-whitegrid',
#  'tableau-colorblind10']
